# %%
# Install the required libraries
from IPython.display import clear_output
try:
  # !pip install pystan pystan~=2.14
  # !pip install fbprophet
  # !pip install hvplot
  # !pip install holoviews
  # !pip install yfinance
except:
  print("Error installing libraries")
finally:
  clear_output()
  print("Libraries successfully installed")
# Out:
# Libraries successfully installed

# %%
# Import the required libraries and dependencies
import pandas as pd
import holoviews as hv
from fbprophet import Prophet
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import hvplot.pandas
import datetime as dt
import requests
import yfinance as yf
# %matplotlib inline

# %%
# Downloading Yahoo Finance API data
futures_data = yf.download("SPY", start="2017-01-01", end="2022-12-01",interval = "1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Stock data from download

display(futures_data.head(5))
display(futures_data.tail(5))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  225.039993  225.830002  223.880005  225.240005  203.788055
# 2017-01-04  225.619995  226.750000  225.610001  226.580002  205.000412
# 2017-01-05  226.270004  226.580002  225.479996  226.399994  204.837570
# 2017-01-06  226.529999  227.750000  225.899994  227.210007  205.570450
# 2017-01-09  226.910004  227.070007  226.419998  226.460007  204.891846
#
#               Volume
# Date
# 2017-01-03  91366500
# 2017-01-04  78744400
# 2017-01-05  78379000
# 2017-01-06  71559900
# 2017-01-09  46939700
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-24  375.890015  380.059998  373.109985  378.869995  378.869995
# 2022-10-25  378.790009  385.250000  378.670013  384.920013  384.920013
# 2022-10-26  381.619995  387.579987  381.350006  382.019989  382.019989
# 2022-10-27  383.070007  385.000000  379.329987  379.980011  379.980011
# 2022-10-28  379.869995  389.519989  379.679993  389.019989  389.019989
#
#                Volume
# Date
# 2022-10-24   85436900
# 2022-10-25   78846300
# 2022-10-26  104087300
# 2022-10-27   81971800
# 2022-10-28  100200100

# %%
# drop unneeded columns
futures_data.drop(columns=["Open","High","Low","Adj Close","Volume"],inplace=True)
display(futures_data.head(5))
display(futures_data.tail(5))
# Out:
#                  Close
# Date
# 2017-01-03  225.240005
# 2017-01-04  226.580002
# 2017-01-05  226.399994
# 2017-01-06  227.210007
# 2017-01-09  226.460007
#                  Close
# Date
# 2022-10-24  378.869995
# 2022-10-25  384.920013
# 2022-10-26  382.019989
# 2022-10-27  379.980011
# 2022-10-28  389.019989

# %%
# reset index
futures_data = futures_data.reset_index()
display(futures_data.head(5))
display(futures_data.tail(5))
# Out:
#         Date       Close
# 0 2017-01-03  225.240005
# 1 2017-01-04  226.580002
# 2 2017-01-05  226.399994
# 3 2017-01-06  227.210007
# 4 2017-01-09  226.460007
#            Date       Close
# 1462 2022-10-24  378.869995
# 1463 2022-10-25  384.920013
# 1464 2022-10-26  382.019989
# 1465 2022-10-27  379.980011
# 1466 2022-10-28  389.019989

# %%
# Review the data types of the DataFrame using the info function
futures_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1467 entries, 0 to 1466
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1467 non-null   datetime64[ns]
#  1   Close   1467 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 23.0 KB

# %%
display(futures_data.head())
display(futures_data.tail())
# Out:
#         Date       Close
# 0 2017-01-03  225.240005
# 1 2017-01-04  226.580002
# 2 2017-01-05  226.399994
# 3 2017-01-06  227.210007
# 4 2017-01-09  226.460007
#            Date       Close
# 1462 2022-10-24  378.869995
# 1463 2022-10-25  384.920013
# 1464 2022-10-26  382.019989
# 1465 2022-10-27  379.980011
# 1466 2022-10-28  389.019989

# %%
# Label the columns ds and y so that the syntax is recognized by Prophet
futures_data.columns = ['ds', 'y']
display(futures_data.head())
display(futures_data.tail())
# Out:
#           ds           y
# 0 2017-01-03  225.240005
# 1 2017-01-04  226.580002
# 2 2017-01-05  226.399994
# 3 2017-01-06  227.210007
# 4 2017-01-09  226.460007
#              ds           y
# 1462 2022-10-24  378.869995
# 1463 2022-10-25  384.920013
# 1464 2022-10-26  382.019989
# 1465 2022-10-27  379.980011
# 1466 2022-10-28  389.019989

# %%
# Call the Prophet function, store as an object
model_futures_data = Prophet()
model_futures_data

# %%
# Fit the time-series model.
model_futures_data.fit(futures_data)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Create a future dataframe to hold predictions for Jan 1, 2023
# Make the prediction go out as far as 1656 hours (approx 67 days)
futures_close_data = model_futures_data.make_future_dataframe(periods=1608, freq='H')

# %%
# View the last five rows of the future_data DataFrame
display(futures_data.tail())
# Out:
#              ds           y
# 1462 2022-10-24  378.869995
# 1463 2022-10-25  384.920013
# 1464 2022-10-26  382.019989
# 1465 2022-10-27  379.980011
# 1466 2022-10-28  389.019989

# %%
# Make the predictions for the trend data using the future_data DataFrame
futures_close_data = model_futures_data.predict(futures_close_data)

# %%
# Display the last five rows of the future_close_data DataFrame
futures_close_data.tail()
# Out:
#                       ds       trend  yhat_lower  yhat_upper  trend_lower  \
# 3070 2023-01-02 20:00:00  375.439685  369.725900  400.335569   372.351250
# 3071 2023-01-02 21:00:00  375.432267  369.444386  399.629816   372.340177
# 3072 2023-01-02 22:00:00  375.424850  369.718934  400.974323   372.329103
# 3073 2023-01-02 23:00:00  375.417432  369.077136  400.378293   372.318030
# 3074 2023-01-03 00:00:00  375.410014  369.069825  399.315725   372.306956
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 3070   378.455807        9.031565              9.031565              9.031565
# 3071   378.450884        9.061767              9.061767              9.061767
# 3072   378.445962        9.090961              9.090961              9.090961
# 3073   378.441039        9.118958              9.118958              9.118958
# 3074   378.436116        9.145601              9.145601              9.145601
#
#         weekly  weekly_lower  weekly_upper    yearly  yearly_lower  \
# 3070 -0.469868     -0.469868     -0.469868  9.501433      9.501433
# 3071 -0.451145     -0.451145     -0.451145  9.512912      9.512912
# 3072 -0.433394     -0.433394     -0.433394  9.524354      9.524354
# 3073 -0.416801     -0.416801     -0.416801  9.535759      9.535759
# 3074 -0.401525     -0.401525     -0.401525  9.547125      9.547125
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 3070      9.501433                   0.0                         0.0
# 3071      9.512912                   0.0                         0.0
# 3072      9.524354                   0.0                         0.0
# 3073      9.535759                   0.0                         0.0
# 3074      9.547125                   0.0                         0.0
#
#       multiplicative_terms_upper        yhat
# 3070                         0.0  384.471250
# 3071                         0.0  384.494034
# 3072                         0.0  384.515810
# 3073                         0.0  384.536389
# 3074                         0.0  384.555615

# %%
# Plot the Prophet predictions for the Future Close data
model_futures_data.plot(futures_close_data)

# %%
# Back Testing the FBProphet Data
# We'll be using a shorten date set within the original future's data set to test the accuracy of the FBProphet model against the other Models.

# %%
# Downloading Yahoo Finance API data
futures_data_backtest = yf.download("SPY", start="2017-01-01", end="2021-12-31",interval = "1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Stock data from download
display(futures_data_backtest.head(5))
display(futures_data_backtest.tail(5))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  225.039993  225.830002  223.880005  225.240005  203.788055
# 2017-01-04  225.619995  226.750000  225.610001  226.580002  205.000443
# 2017-01-05  226.270004  226.580002  225.479996  226.399994  204.837570
# 2017-01-06  226.529999  227.750000  225.899994  227.210007  205.570435
# 2017-01-09  226.910004  227.070007  226.419998  226.460007  204.891815
#
#               Volume
# Date
# 2017-01-03  91366500
# 2017-01-04  78744400
# 2017-01-05  78379000
# 2017-01-06  71559900
# 2017-01-09  46939700
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-12-23  468.750000  472.190002  468.640015  470.600006  465.213684
# 2021-12-27  472.059998  477.309998  472.010010  477.260010  471.797455
# 2021-12-28  477.720001  478.809998  476.059998  476.869995  471.411896
# 2021-12-29  476.980011  478.559998  475.920013  477.480011  472.014954
# 2021-12-30  477.929993  479.000000  475.670013  476.160004  470.710052
#
#               Volume
# Date
# 2021-12-23  56439700
# 2021-12-27  56808600
# 2021-12-28  47274600
# 2021-12-29  54503000
# 2021-12-30  55329000

# %%
# Cleaning up the Backtesting DataFrame
# drop unneeded columns
futures_data_backtest.drop(columns=["Open","High","Low","Adj Close","Volume"],inplace=True)
# reset index
futures_data_backtest = futures_data_backtest.reset_index()
display(futures_data_backtest.head(5))
display(futures_data_backtest.tail(5))
# Out:
#         Date       Close
# 0 2017-01-03  225.240005
# 1 2017-01-04  226.580002
# 2 2017-01-05  226.399994
# 3 2017-01-06  227.210007
# 4 2017-01-09  226.460007
#            Date       Close
# 1253 2021-12-23  470.600006
# 1254 2021-12-27  477.260010
# 1255 2021-12-28  476.869995
# 1256 2021-12-29  477.480011
# 1257 2021-12-30  476.160004

# %%
# Review the data types of the DataFrame using the info function
futures_data_backtest.info()
# Review DataFrame
display(futures_data_backtest.head())
display(futures_data_backtest.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   datetime64[ns]
#  1   Close   1258 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 19.8 KB
#         Date       Close
# 0 2017-01-03  225.240005
# 1 2017-01-04  226.580002
# 2 2017-01-05  226.399994
# 3 2017-01-06  227.210007
# 4 2017-01-09  226.460007
#            Date       Close
# 1253 2021-12-23  470.600006
# 1254 2021-12-27  477.260010
# 1255 2021-12-28  476.869995
# 1256 2021-12-29  477.480011
# 1257 2021-12-30  476.160004

# %%
# Label the columns ds and y so that the syntax is recognized by Prophet
futures_data_backtest.columns = ['ds', 'y']
display(futures_data_backtest.head())
display(futures_data_backtest.tail())
# Out:
#           ds           y
# 0 2017-01-03  225.240005
# 1 2017-01-04  226.580002
# 2 2017-01-05  226.399994
# 3 2017-01-06  227.210007
# 4 2017-01-09  226.460007
#              ds           y
# 1253 2021-12-23  470.600006
# 1254 2021-12-27  477.260010
# 1255 2021-12-28  476.869995
# 1256 2021-12-29  477.480011
# 1257 2021-12-30  476.160004

# %%
# Call the Prophet function, store as an object
model_futures_data_backtest = Prophet()
model_futures_data_backtest

# %%
# Fit the time-series model.
model_futures_data_backtest.fit(futures_data_backtest)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Create a future dataframe to hold predictions to Oct 26, 2022
# Make the prediction go out as far as 300 days
futures_close_data_backtest = model_futures_data_backtest.make_future_dataframe(periods=300, freq='D')

# %%
# View the last five rows of the future_data_backtest DataFrame
display(futures_close_data_backtest.tail())
# Out:
#              ds
# 1553 2022-10-22
# 1554 2022-10-23
# 1555 2022-10-24
# 1556 2022-10-25
# 1557 2022-10-26

# %%
# Make the predictions for the trend data using the future_data DataFrame
futures_close_data_backtest = model_futures_data_backtest.predict(futures_close_data_backtest)

# %%
# Display the last five rows of the future_close_data DataFrame
futures_close_data_backtest.tail(1)
# Out:
#              ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 1557 2022-10-26  565.327871  458.705011  657.616307   466.033222   663.183186
#
#       additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 1557       -6.745211             -6.745211             -6.745211  0.345248
#
#       weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 1557      0.345248      0.345248 -7.090459     -7.090459     -7.090459
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 1557                   0.0                         0.0
#
#       multiplicative_terms_upper       yhat
# 1557                         0.0  558.58266

# %%
# Plot the Prophet predictions for the Future Close data
model_futures_data_backtest.plot(futures_close_data_backtest)

# %%
# combine DataFrames for metric calculation
xdf = futures_data
xdf["predicted"] = futures_close_data["yhat"]
xdf
# Out:
#              ds           y   predicted
# 0    2017-01-03  225.240005  231.007156
# 1    2017-01-04  226.580002  231.413629
# 2    2017-01-05  226.399994  231.659673
# 3    2017-01-06  227.210007  231.914340
# 4    2017-01-09  226.460007  232.780123
# ...         ...         ...         ...
# 1462 2022-10-24  378.869995  383.730747
# 1463 2022-10-25  384.920013  384.201458
# 1464 2022-10-26  382.019989  384.489732
# 1465 2022-10-27  379.980011  384.635584
# 1466 2022-10-28  389.019989  384.809601
#
# [1467 rows x 3 columns]

# %%
# setup values for the metric calculation
y = xdf["y"]
predicted_y_values = xdf["predicted"]

# %%
# Compute the metrics for the model
# y = close column of original data frame
# predicted y =  
r2 = r2_score(y, predicted_y_values)
mse = mean_squared_error(y, predicted_y_values)
rmse = np.sqrt(mse)
std = np.std(y)

# Print relevant metrics.
print(f"The r2 is {r2}.")
print(f"The mean squared error is {mse}.")
print(f"The root mean squared error is {rmse}.")
print(f"The standard deviation is {std}.")
# Out:
# The r2 is 0.9739142789695292.
# The mean squared error is 133.504176910634.
# The root mean squared error is 11.554400759478355.
# The standard deviation is 71.53951706100618.
